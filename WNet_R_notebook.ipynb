# %% [markdown]
# #Mounting google drive

# %%
from google.colab import drive
import os
import sys

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #Importing Kaggle dataset: PASCAL VOC 2012

# %%
# os.environ['KAGGLE_CONFIG_DIR'] = "/content/gdrive/My Drive/Kaggle"
# %cd /content/gdrive/My Drive/Kaggle

# !kaggle datasets download -d huanghanchina/pascal-voc-2012

# %%
## unzipping the files and removing the .zip files
# !unzip \*.zip  && rm *.zip

# %% [markdown]
# resizing and normalizing all the images

# %%
py_file_location = "/content/gdrive/MyDrive/WNet_project/WNet_R"
sys.path.insert(0, os.path.abspath(py_file_location))
# %cd /content/gdrive/MyDrive/WNet_project/WNet_R
# Out:
# /content/gdrive/MyDrive/WNet_project/WNet_R

# %%
#!pip install torchinfo 
#!python train.py
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np

from torch.utils.tensorboard import SummaryWriter
from WNet import WNet
from configure import Config
from torchinfo import summary
from train import WNet_train

#importing configurations
config = Config("train")

#inizialization of a new WNet model
model = WNet(config.K, config.dropout, config.ch_mul, config.in_chans, config.out_chans)

#summary of the model 
#summary(model, input_size=(config.BatchSize, config.in_chans, config.inputsize[0], config.inputsize[1]))

#training
model, summary_writer = WNet_train(model, config, summary = True)
torch.save(model.state_dict(), config.saving_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...
